# %% [markdown]
# ## Prerequisites

# %%
import os, sys
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from utils.data_utils import load_dataset ,load_file, split_ids
from utils.preprocessing import create_batch_sequences
from utils.evaluate import compare_events
from scipy.signal import find_peaks
np.random.seed(123)

# %% [markdown]
# For each valid trial, the relevant data and information are saved in **five** different data files:
# - sub-\<label\>_task-\<label\>[_run-\<label\>]_events.tsv
# - sub-\<label\>_task-\<label\>[_run-\<label\>]_tracksys-imu_channels.tsv
# - sub-\<label\>_task-\<label\>[_run-\<label\>]_tracksys-imu_motion.tsv
# - sub-\<label\>_task-\<label\>[_run-\<label\>]_tracksys-omc_channels.tsv
# - sub-\<label\>_task-\<label\>[_run-\<label\>]_tracksys-omc_motion.tsv
#
# As we only consinder **walk** trials, we can look for any **_events.tsv** file that contains **_task-walk** in the filename.

# %% [markdown]
# ## Get data

# %%
# Set root directory
ROOT_DIR = "/mnt/neurogeriatrics_data/Keep Control/Data/lab dataset/rawdata" if sys.platform == "linux" else "Z:\\Keep Control\\Data\\lab dataset\\rawdata"

# Split subjects into a train, validation, and test set
train_ids, val_ids, test_ids = split_ids(ROOT_DIR, by=["gender", "participant_type"])
print(f"# of subjects in train set:\t{len(train_ids):d}\t{train_ids[:5]}")
print(f"# of subjects in val set:\t{len(val_ids):d}\t{val_ids[:5]}")
print(f"# of subjects in test set:\t{len(test_ids):d}\t{test_ids[:5]}")
# Out:
# # of subjects in train set:	62	['sub-pp147', 'sub-pp039', 'sub-pp135', 'sub-pp157', 'sub-pp106']
# # of subjects in val set:	49	['sub-pp047', 'sub-pp153', 'sub-pp168', 'sub-pp125', 'sub-pp010']
# # of subjects in test set:	49	['sub-pp156', 'sub-pp155', 'sub-pp167', 'sub-pp126', 'sub-pp165']

# %%
# User settings
TRACKED_POINTS = ["left_ankle", "right_ankle", "left_shank", "right_shank"]
INCL_MAGN = False
NORMALIZE = True

# %%
# Get datasets
ds_train = load_dataset(ROOT_DIR, sub_ids=train_ids, tracked_points=TRACKED_POINTS, incl_magn=INCL_MAGN, normalize=NORMALIZE)
ds_val = load_dataset(ROOT_DIR, sub_ids=val_ids, tracked_points=TRACKED_POINTS, normalize=NORMALIZE)
ds_test = load_dataset(ROOT_DIR, sub_ids=test_ids, tracked_points=TRACKED_POINTS, normalize=NORMALIZE)

# %%
WIN_LEN = 400
STEP_LEN = 200
train_data, train_targets, ds_train_batches = create_batch_sequences(ds_train, win_len=WIN_LEN, step_len=STEP_LEN)
val_data, val_targets, ds_val_batches = create_batch_sequences(ds_val, win_len=WIN_LEN, step_len=STEP_LEN)

# %% [markdown]
# ## Build model

# %%
from tensorflow import keras
from tcn import TCN, tcn_full_summary

# %%
NB_FILTERS = 16
KERNEL_SIZE = 5
DILATIONS = [1, 2, 4]
PADDING = "same"

# %%
def build_model(input_dim, class_names):
    # Define layers
    inputs = keras.layers.Input(shape=(None, input_dim), name="inputs")
    tcn = TCN(
        nb_filters=NB_FILTERS,
        kernel_size=KERNEL_SIZE,
        dilations=DILATIONS,
        padding=PADDING,
        use_batch_norm=True,
        use_skip_connections=True,
        return_sequences=True,
        name="tcn_layer"
    )(inputs)
    outputs = []
    for i in range(len(class_names)):
        outputs.append(keras.layers.Dense(units=1, activation="sigmoid", name=class_names[i])(tcn))
    
    # Instantiate model
    model = keras.models.Model(inputs=inputs, outputs=outputs, name="tcn_model")

    # Compile
    model.compile(loss=keras.losses.MeanSquaredError(), optimizer=keras.optimizers.Adam(learning_rate=0.0003))
    return model

# %%
model = build_model(train_data.shape[-1], class_names=list(train_targets.keys()))
model.summary()
# Out:
# Model: "tcn_model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  inputs (InputLayer)            [(None, None, 6)]    0           []
#
#  tcn_layer (TCN)                (None, None, 16)     7472        ['inputs[0][0]']
#
#  initial_contact (Dense)        (None, None, 1)      17          ['tcn_layer[0][0]']
#
#  final_contact (Dense)          (None, None, 1)      17          ['tcn_layer[0][0]']
#
# ==================================================================================================
# Total params: 7,506
# Trainable params: 7,314
# Non-trainable params: 192
# __________________________________________________________________________________________________

# %%
history = model.fit(x=train_data, y=train_targets, batch_size=16, epochs=5, validation_data=(val_data, val_targets))
# Out:
# Epoch 1/5
# 211/211 [==============================] - 6s 9ms/step - loss: 0.3275 - initial_contact_loss: 0.0307 - final_contact_loss: 0.2968 - val_loss: 0.2887 - val_initial_contact_loss: 0.0301 - val_final_contact_loss: 0.2586
# Epoch 2/5
# 211/211 [==============================] - 2s 8ms/step - loss: 0.1433 - initial_contact_loss: 0.0201 - final_contact_loss: 0.1232 - val_loss: 0.1060 - val_initial_contact_loss: 0.0190 - val_final_contact_loss: 0.0870
# Epoch 3/5
# 211/211 [==============================] - 2s 9ms/step - loss: 0.0804 - initial_contact_loss: 0.0167 - final_contact_loss: 0.0636 - val_loss: 0.0428 - val_initial_contact_loss: 0.0162 - val_final_contact_loss: 0.0266
# Epoch 4/5
# 211/211 [==============================] - 2s 8ms/step - loss: 0.0396 - initial_contact_loss: 0.0142 - final_contact_loss: 0.0254 - val_loss: 0.0326 - val_initial_contact_loss: 0.0141 - val_final_contact_loss: 0.0185
# Epoch 5/5
# 211/211 [==============================] - 2s 8ms/step - loss: 0.0268 - initial_contact_loss: 0.0123 - final_contact_loss: 0.0144 - val_loss: 0.0281 - val_initial_contact_loss: 0.0130 - val_final_contact_loss: 0.0151

# %%
fig, ax = plt.subplots(1, 1)
ax.plot(history.history["loss"], 'ro-', label='training')
ax.plot(history.history["val_loss"], 'b*-', label="validation")
plt.show()

# %% [markdown]
# ### Evaluate on test set

# %%
def fancy_plot(ds_test, ix_sub_id, predictions, ix_IC_pred, ix_FC_pred):
    cm = 1/2.54

    fig, axs = plt.subplots(1+len(ds_test[ix_sub_id]["targets"].keys()), 1, figsize=(16*cm, 9*cm), sharex=True, gridspec_kw={"height_ratios": [3, 1, 1]})
    axs[0].plot(np.arange(ds_test[ix_sub_id]["data"].shape[0]), ds_test[ix_sub_id]["data"][:,5], ls="-", c=(0, 0, 0), alpha=0.3)
    axs[0].plot(np.argwhere(ds_test[ix_sub_id]["targets"]["initial_contact"]==1)[:,0], ds_test[ix_sub_id]["data"][np.argwhere(ds_test[ix_sub_id]["targets"]["initial_contact"]==1)[:,0],5], ls="none", marker="o", mfc="none", mec=(0, 0, 1))
    axs[0].plot(np.argwhere(ds_test[ix_sub_id]["targets"]["final_contact"]==1)[:,0], ds_test[ix_sub_id]["data"][np.argwhere(ds_test[ix_sub_id]["targets"]["final_contact"]==1)[:,0],5], ls="none", marker="o", mfc="none", mec=(0, 0.65, 0))
    axs[0].xaxis.set_minor_locator(plt.MultipleLocator(10))
    axs[0].grid(which="both", axis="both", c=(0, 0, 0), alpha=0.1, ls=":")
    axs[0].set_xlim([0, ds_test[ix_sub_id]["data"].shape[0]])

    axs[1].plot(np.arange(ds_test[ix_sub_id]["targets"]["initial_contact"].shape[0]), ds_test[ix_sub_id]["targets"]["initial_contact"][:,0], ls="-", c=(0, 0, 1), lw=2, alpha=0.2)
    axs[1].plot(np.arange(predictions[0][0].shape[0]), predictions[0][0][:,0], ls="-", lw=1, c=(0, 0, 1))
    axs[1].plot(ix_IC_pred, predictions[0][0][ix_IC_pred,0], ls="none", marker="o", mfc="none", mec=(0, 0, 1))
    axs[1].set_ylim([0.1, 1.1])
    axs[1].set_yticks([0, 1])
    axs[1].set_ylabel("Pr(IC)")
    axs[1].yaxis.set_minor_locator(plt.MultipleLocator(0.25))
    axs[1].grid(which="both", axis="both", c=(0, 0, 0), alpha=0.1, ls=":")

    axs[2].plot(np.arange(ds_test[ix_sub_id]["targets"]["final_contact"].shape[0]), ds_test[ix_sub_id]["targets"]["final_contact"][:,0], ls="-", c=(0, 0.65, 0), lw=2, alpha=0.2)
    axs[2].plot(np.arange(predictions[1][0].shape[0]), predictions[1][0][:,0], ls="-", lw=1, c=(0, 0.65, 0))
    axs[2].plot(ix_FC_pred, predictions[1][0][ix_FC_pred,0], ls="none", marker="o", mfc="none", mec=(0, 0.65, 0))
    axs[2].set_ylim([0.1, 1.1])
    axs[2].set_yticks([0, 1])
    axs[2].set_ylabel("Pr(FC)")
    axs[2].yaxis.set_minor_locator(plt.MultipleLocator(0.25))
    axs[2].grid(which="both", axis="both", c=(0, 0, 0), alpha=0.1, ls=":")
    axs[2].set_xlabel("sample")

    plt.tight_layout()
    plt.savefig(os.path.join("/home/robbin/Desktop/fig/20220222", ds_test[ix_sub_id]["filename_prefix"]+"_"+ds_test[ix_sub_id]["left_or_right"]+"_predictions.png"), dpi=300)
    plt.close()
    return

# %%
def add_metrics(ds_test, ix_sub_id, visualize=True):
    # Get data array
    X = ds_test[ix_sub_id]["data"]
    X = np.expand_dims(X, axis=0)
    
    # Predict
    predictions = model.predict(X)
    
    # Get true and predicted events
    ix_IC_true, _ = find_peaks(ds_test[ix_sub_id]["targets"]["initial_contact"][:,0], height=0.4, distance=100)
    ix_FC_true, _ = find_peaks(ds_test[ix_sub_id]["targets"]["final_contact"][:,0], height=0.4, distance=100)
    ix_IC_pred, _ = find_peaks(predictions[0][0][:,0], height=0.4, distance=100)
    ix_FC_pred, _ = find_peaks(predictions[1][0][:,0], height=0.4, distance=100)
    
    event_type, ix_ref, ix_pred = [], [], []
    # Initial contacts
    ann2pred, pred2ann, dt = compare_events(ix_IC_true, ix_IC_pred)
    for i in range(len(ix_IC_true)):
        event_type.append("IC")
        ix_ref.append(ix_IC_true[i])
        if ann2pred[i] > -999:
            # print(f"{ix_IC_true[i]:>6d} : {ix_IC_pred[ann2pred[i]]}")
            ix_pred.append(ix_IC_pred[ann2pred[i]])
        else:
            # print(f"{ix_IC_true[i]:>6d} : {'n/a':s}")
            ix_pred.append("n/a")
    for j in range(len(ix_IC_pred)):
        if pred2ann[j] == -999:
            event_type.append("IC")
            ix_ref.append("n/a")
            ix_pred.append(ix_IC_pred[j])
            # print(f"{'n/a':>6s} : {ix_IC_pred[j]}")
            
    # Final contacts
    ann2pred, pred2ann, dt = compare_events(ix_FC_true, ix_FC_pred)
    for i in range(len(ix_FC_true)):
        event_type.append("FC")
        ix_ref.append(ix_FC_true[i])
        if ann2pred[i] > -999:
            # print(f"{ix_FC_true[i]:>6d} : {ix_FC_pred[ann2pred[i]]}")
            ix_pred.append(ix_FC_pred[ann2pred[i]])
        else:
            # print(f"{ix_FC_true[i]:>6d} : {'n/a':s}")
            ix_pred.append("n/a")
    for j in range(len(ix_FC_pred)):
        if pred2ann[j] == -999:
            event_type.append("FC")
            ix_ref.append("n/a")
            ix_pred.append(ix_FC_pred[j])
            # print(f"{'n/a':>6s} : {ix_FC_pred[j]}")
    
    sub_id = [ds_test[ix_sub_id]["filename_prefix"][4:9] for _ in range(len(event_type))]
    filenames = [ds_test[ix_sub_id]["filename_prefix"] for _ in range(len(event_type))]
    side = [ds_test[ix_sub_id]["left_or_right"] for _ in range(len(event_type))]
    
    # Visualize
    if visualize:
        fancy_plot(ds_test=ds_test, ix_sub_id=ix_sub_id, predictions=predictions, ix_IC_pred=ix_IC_pred, ix_FC_pred=ix_FC_pred)
    
    return sub_id, filenames, side, event_type, ix_ref, ix_pred

# %%
sub_ids, filenames, sides, event_types, ix_refs, ix_preds = [], [], [], [], [], []
for i in range(len(ds_test)):
    print(f"{i:>3d}: {ds_test[i]['filename_prefix']+'_'+ds_test[i]['left_or_right']:s}")
    sub_id, filename, side, event_type, ix_ref, ix_pred = add_metrics(ds_test, ix_sub_id=i)
    sub_ids += sub_id
    filenames += filename
    sides += side
    event_types += event_type
    ix_refs += ix_ref
    ix_preds += ix_pred
# Out:
#   0: sub-pp156_task-walkFast_left
#   1: sub-pp156_task-walkFast_right
#   2: sub-pp156_task-walkPreferred_left
#   3: sub-pp156_task-walkPreferred_right
#   4: sub-pp156_task-walkSlow_left
#   5: sub-pp156_task-walkSlow_right
#   6: sub-pp155_task-walkFast_left
#   7: sub-pp155_task-walkFast_right
#   8: sub-pp155_task-walkPreferred_left
#   9: sub-pp155_task-walkPreferred_right
#  10: sub-pp155_task-walkSlow_left
#  11: sub-pp155_task-walkSlow_right
#  12: sub-pp167_task-walkFast_left
# 3 gait events annotated, but none were detected
#  13: sub-pp167_task-walkFast_right
#  14: sub-pp167_task-walkPreferred_left
#  15: sub-pp167_task-walkPreferred_right
#  16: sub-pp167_task-walkSlow_left
#  17: sub-pp167_task-walkSlow_right
#  18: sub-pp126_task-walkFast_left
#  19: sub-pp126_task-walkFast_right
#  20: sub-pp126_task-walkPreferred_left
#  21: sub-pp126_task-walkPreferred_right
#  22: sub-pp126_task-walkSlow_left
#  23: sub-pp126_task-walkSlow_right
#  24: sub-pp165_task-walkFast_left
#  25: sub-pp165_task-walkFast_right
#  26: sub-pp165_task-walkPreferred_left
#  27: sub-pp165_task-walkPreferred_right
#  28: sub-pp165_task-walkSlow_left
#  29: sub-pp165_task-walkSlow_right
# 5 gait events annotated, but none were detected
#  30: sub-pp154_task-walkFast_left
#  31: sub-pp154_task-walkFast_right
#  32: sub-pp154_task-walkPreferred_left
#  33: sub-pp154_task-walkPreferred_right
#  34: sub-pp154_task-walkSlow_left
#  35: sub-pp154_task-walkSlow_right
#  36: sub-pp121_task-walkFast_left
#  37: sub-pp121_task-walkFast_right
#  38: sub-pp121_task-walkSlow_left
#  39: sub-pp121_task-walkSlow_right
#  40: sub-pp113_task-walkFast_run-off_left
#  41: sub-pp113_task-walkFast_run-off_right
#  42: sub-pp113_task-walkPreferred_run-off_left
#  43: sub-pp113_task-walkPreferred_run-off_right
#  44: sub-pp113_task-walkSlow_run-off_left
#  45: sub-pp113_task-walkSlow_run-off_right
#  46: sub-pp053_task-walkFast_run-on_left
#  47: sub-pp053_task-walkFast_run-on_right
#  48: sub-pp053_task-walkPreferred_run-on_left
#  49: sub-pp053_task-walkPreferred_run-on_right
#  50: sub-pp053_task-walkSlow_run-on_left
#  51: sub-pp053_task-walkSlow_run-on_right
#  52: sub-pp059_task-walkFast_run-off_left
#  53: sub-pp059_task-walkFast_run-off_right
#  54: sub-pp059_task-walkPreferred_run-off_left
#  55: sub-pp059_task-walkPreferred_run-off_right
#  56: sub-pp059_task-walkSlow_run-off_left
#  57: sub-pp059_task-walkSlow_run-off_right
#  58: sub-pp102_task-walkFast_run-off_left
#  59: sub-pp102_task-walkFast_run-off_right
# 4 gait events annotated, but none were detected
#  60: sub-pp102_task-walkFast_run-on_left
#  61: sub-pp102_task-walkFast_run-on_right
#  62: sub-pp102_task-walkPreferred_run-off_left
#  63: sub-pp102_task-walkPreferred_run-off_right
#  64: sub-pp102_task-walkPreferred_run-on_left
#  65: sub-pp102_task-walkPreferred_run-on_right
#  66: sub-pp102_task-walkSlow_run-off_left
#  67: sub-pp102_task-walkSlow_run-off_right
#  68: sub-pp102_task-walkSlow_run-on_left
#  69: sub-pp102_task-walkSlow_run-on_right
#  70: sub-pp066_task-walkFast_left
#  71: sub-pp066_task-walkFast_right
#  72: sub-pp066_task-walkPreferred_left
#  73: sub-pp066_task-walkPreferred_right
#  74: sub-pp066_task-walkSlow_left
#  75: sub-pp066_task-walkSlow_right
# 4 gait events annotated, but none were detected
#  76: sub-pp014_task-walkFast_left
#  77: sub-pp014_task-walkFast_right
#  78: sub-pp014_task-walkPreferred_left
#  79: sub-pp014_task-walkPreferred_right
#  80: sub-pp014_task-walkSlow_left
#  81: sub-pp014_task-walkSlow_right
#  82: sub-pp089_task-walkFast_left
#  83: sub-pp089_task-walkFast_right
#  84: sub-pp089_task-walkPreferred_left
#  85: sub-pp089_task-walkPreferred_right
#  86: sub-pp089_task-walkSlow_left
#  87: sub-pp089_task-walkSlow_right
#  88: sub-pp040_task-walkPreferred_left
#  89: sub-pp040_task-walkPreferred_right
#  90: sub-pp040_task-walkSlow_left
#  91: sub-pp040_task-walkSlow_right
#  92: sub-pp013_task-walkFast_left
#  93: sub-pp013_task-walkFast_right
#  94: sub-pp013_task-walkPreferred_left
#  95: sub-pp013_task-walkPreferred_right
#  96: sub-pp013_task-walkSlow_left
#  97: sub-pp013_task-walkSlow_right
#  98: sub-pp045_task-walkFast_left
#  99: sub-pp045_task-walkFast_right
# 100: sub-pp045_task-walkPreferred_left
# 101: sub-pp045_task-walkPreferred_right
# 102: sub-pp045_task-walkSlow_left
# 103: sub-pp045_task-walkSlow_right
# 104: sub-pp031_task-walkFast_left
# 105: sub-pp031_task-walkFast_right
# 106: sub-pp031_task-walkPreferred_left
# 107: sub-pp031_task-walkPreferred_right
# 108: sub-pp031_task-walkSlow_left
# 109: sub-pp031_task-walkSlow_right
# 110: sub-pp050_task-walkFast_left
# 111: sub-pp050_task-walkFast_right
# 112: sub-pp050_task-walkPreferred_left
# 113: sub-pp050_task-walkPreferred_right
# 114: sub-pp050_task-walkSlow_left
# 115: sub-pp050_task-walkSlow_right
# 116: sub-pp044_task-walkFast_left
# 117: sub-pp044_task-walkFast_right
# 118: sub-pp044_task-walkPreferred_left
# 119: sub-pp044_task-walkPreferred_right
# 120: sub-pp044_task-walkSlow_left
# 121: sub-pp044_task-walkSlow_right
# 122: sub-pp123_task-walkFast_left
# 123: sub-pp123_task-walkFast_right
# 124: sub-pp123_task-walkPreferred_left
# 125: sub-pp123_task-walkPreferred_right
# 126: sub-pp123_task-walkSlow_left
# 127: sub-pp123_task-walkSlow_right
# 128: sub-pp029_task-walkFast_left
# 129: sub-pp029_task-walkFast_right
# 130: sub-pp029_task-walkPreferred_left
# 131: sub-pp029_task-walkPreferred_right
# 132: sub-pp029_task-walkSlow_left
# 133: sub-pp029_task-walkSlow_right
# 134: sub-pp058_task-walkFastSchub_left
# 135: sub-pp058_task-walkFastSchub_right
# 136: sub-pp058_task-walkFast_left
# 137: sub-pp058_task-walkFast_right
# 138: sub-pp058_task-walkPreferredSchub_left
# 139: sub-pp058_task-walkPreferredSchub_right
# 5 gait events annotated, but none were detected
# 140: sub-pp058_task-walkPreferred_left
# 141: sub-pp058_task-walkPreferred_right
# 142: sub-pp058_task-walkSlowSchub_left
# 143: sub-pp058_task-walkSlowSchub_right
# 144: sub-pp058_task-walkSlow_left
# 145: sub-pp058_task-walkSlow_right
# 146: sub-pp078_task-walkFast_left
# 147: sub-pp078_task-walkFast_right
# 148: sub-pp078_task-walkPreferred_left
# 149: sub-pp078_task-walkPreferred_right
# 150: sub-pp078_task-walkSlow_left
# 151: sub-pp078_task-walkSlow_right
# 152: sub-pp079_task-walkFast_left
# 153: sub-pp079_task-walkFast_right
# 154: sub-pp079_task-walkPreferred_left
# 155: sub-pp079_task-walkPreferred_right
# 156: sub-pp079_task-walkSlow_left
# 157: sub-pp079_task-walkSlow_right
# 158: sub-pp028_task-walkFast_left
# 159: sub-pp028_task-walkFast_right
# 160: sub-pp028_task-walkPreferred_left
# 161: sub-pp028_task-walkPreferred_right
# 162: sub-pp028_task-walkSlow_left
# 163: sub-pp028_task-walkSlow_right
# 164: sub-pp065_task-walkFast_left
# 165: sub-pp065_task-walkFast_right
# 166: sub-pp065_task-walkPreferred_left
# 167: sub-pp065_task-walkPreferred_right
# 168: sub-pp065_task-walkSlow_left
# 169: sub-pp065_task-walkSlow_right
# 170: sub-pp140_task-walkFast_run-on_left
# 171: sub-pp140_task-walkFast_run-on_right
# 172: sub-pp140_task-walkPreferred_run-on_left
# 173: sub-pp140_task-walkPreferred_run-on_right
# 174: sub-pp140_task-walkSlow_run-on_left
# 175: sub-pp140_task-walkSlow_run-on_right
# 176: sub-pp069_task-walkFast_run-off_left
# 177: sub-pp069_task-walkFast_run-off_right
# 178: sub-pp069_task-walkPreferred_run-off_left
# 179: sub-pp069_task-walkPreferred_run-off_right
# 180: sub-pp069_task-walkSlow_run-off_left
# 181: sub-pp069_task-walkSlow_run-off_right
# 182: sub-pp022_task-walkFast_run-off_left
# 183: sub-pp022_task-walkFast_run-off_right
# 184: sub-pp022_task-walkFast_run-on_left
# 185: sub-pp022_task-walkFast_run-on_right
# 186: sub-pp022_task-walkPreferred_run-off_left
# 187: sub-pp022_task-walkPreferred_run-off_right
# 188: sub-pp022_task-walkPreferred_run-on_left
# 189: sub-pp022_task-walkPreferred_run-on_right
# 190: sub-pp022_task-walkSlow_run-on_left
# 191: sub-pp022_task-walkSlow_run-on_right
# 192: sub-pp075_task-walkFast_run-off_left
# 193: sub-pp075_task-walkFast_run-off_right
# 194: sub-pp075_task-walkFast_run-on_left
# 195: sub-pp075_task-walkFast_run-on_right
# 196: sub-pp075_task-walkPreferred_run-off_left
# 197: sub-pp075_task-walkPreferred_run-off_right
# 198: sub-pp075_task-walkPreferred_run-on_left
# 199: sub-pp075_task-walkPreferred_run-on_right
# 200: sub-pp075_task-walkSlow_run-off_left
# 201: sub-pp075_task-walkSlow_run-off_right
# 202: sub-pp075_task-walkSlow_run-on_left
# 203: sub-pp075_task-walkSlow_run-on_right
# 204: sub-pp046_task-walkFast_run-off_left
# 205: sub-pp046_task-walkFast_run-off_right
# 206: sub-pp046_task-walkFast_run-on_left
# 207: sub-pp046_task-walkFast_run-on_right
# 208: sub-pp046_task-walkPreferred_run-off_left
# 209: sub-pp046_task-walkPreferred_run-off_right
# 210: sub-pp046_task-walkPreferred_run-on_left
# 211: sub-pp046_task-walkPreferred_run-on_right
# 212: sub-pp046_task-walkSlow_run-off_left
# 213: sub-pp046_task-walkSlow_run-off_right
# 214: sub-pp046_task-walkSlow_run-on_left
# 215: sub-pp046_task-walkSlow_run-on_right
# 216: sub-pp061_task-walkFast_left
# 217: sub-pp061_task-walkFast_right
# 218: sub-pp061_task-walkPreferred_left
# 219: sub-pp061_task-walkPreferred_right
# 220: sub-pp061_task-walkSlow_left
# 221: sub-pp061_task-walkSlow_right
# 222: sub-pp003_task-walkFast_left
# 223: sub-pp003_task-walkFast_right
# 224: sub-pp003_task-walkPreferred_left
# 225: sub-pp003_task-walkPreferred_right
# 226: sub-pp003_task-walkSlow_left
# 227: sub-pp003_task-walkSlow_right
# 228: sub-pp132_task-walkFast_left
# 229: sub-pp132_task-walkFast_right
# 230: sub-pp132_task-walkPreferred_left
# 231: sub-pp132_task-walkPreferred_right
# 232: sub-pp132_task-walkSlow_left
# 233: sub-pp132_task-walkSlow_right
# 234: sub-pp052_task-walkFast_left
# 235: sub-pp052_task-walkFast_right
# 2 gait events annotated, but none were detected
# 236: sub-pp052_task-walkPreferred_left
# 237: sub-pp052_task-walkPreferred_right
# 238: sub-pp052_task-walkSlow_left
# 239: sub-pp052_task-walkSlow_right
# 240: sub-pp057_task-walkFast_left
# 241: sub-pp057_task-walkFast_right
# 242: sub-pp057_task-walkPreferred_left
# 243: sub-pp057_task-walkPreferred_right
# 244: sub-pp057_task-walkSlow_left
# 245: sub-pp057_task-walkSlow_right
# 246: sub-pp063_task-walkFast_left
# 247: sub-pp063_task-walkFast_right
# 248: sub-pp063_task-walkPreferred_left
# 249: sub-pp063_task-walkPreferred_right
# 250: sub-pp063_task-walkSlow_left
# 251: sub-pp063_task-walkSlow_right
# 252: sub-pp072_task-walkFast_left
# 253: sub-pp072_task-walkFast_right
# 254: sub-pp072_task-walkPreferred_left
# 255: sub-pp072_task-walkPreferred_right
# 256: sub-pp072_task-walkSlow_left
# 257: sub-pp072_task-walkSlow_right
# 258: sub-pp070_task-walkFast_left
# 259: sub-pp070_task-walkFast_right
# 260: sub-pp070_task-walkPreferred_left
# 261: sub-pp070_task-walkPreferred_right
# 262: sub-pp070_task-walkSlow_left
# 263: sub-pp070_task-walkSlow_right
# 264: sub-pp048_task-walkFast_left
# 265: sub-pp048_task-walkFast_right
# 266: sub-pp048_task-walkPreferred_left
# 267: sub-pp048_task-walkPreferred_right
# 268: sub-pp048_task-walkSlow_left
# 269: sub-pp048_task-walkSlow_right
# 270: sub-pp012_task-walkFast_left
# 271: sub-pp012_task-walkFast_right
# 272: sub-pp012_task-walkPreferred_left
# 273: sub-pp012_task-walkPreferred_right
# 274: sub-pp012_task-walkSlow_left
# 275: sub-pp012_task-walkSlow_right
# 276: sub-pp103_task-walkFast_left
# 277: sub-pp103_task-walkFast_right
# 278: sub-pp103_task-walkPreferred_left
# 279: sub-pp103_task-walkPreferred_right
# 280: sub-pp103_task-walkSlow_left
# 281: sub-pp103_task-walkSlow_right
# 282: sub-pp136_task-walkFast_left
# 283: sub-pp136_task-walkFast_right
# 284: sub-pp136_task-walkPreferred_left
# 285: sub-pp136_task-walkPreferred_right
# 286: sub-pp136_task-walkSlow_left
# 287: sub-pp136_task-walkSlow_right
# 288: sub-pp149_task-walkFast_left
# 289: sub-pp149_task-walkFast_right
# 290: sub-pp149_task-walkPreferred_left
# 291: sub-pp149_task-walkPreferred_right
# 292: sub-pp149_task-walkSlow_left
# 293: sub-pp149_task-walkSlow_right
# 294: sub-pp112_task-walkPreferred_left
# 295: sub-pp112_task-walkPreferred_right
# 296: sub-pp112_task-walkSlow_left
# 297: sub-pp112_task-walkSlow_right
# 298: sub-pp025_task-walkFast_left
# 299: sub-pp025_task-walkFast_right
# 300: sub-pp025_task-walkPreferred_left
# 301: sub-pp025_task-walkPreferred_right
# 302: sub-pp025_task-walkSlow_left
# 303: sub-pp025_task-walkSlow_right
# 304: sub-pp033_task-walkFast_left
# 305: sub-pp033_task-walkFast_right
# 306: sub-pp033_task-walkPreferred_left
# 307: sub-pp033_task-walkPreferred_right
# 308: sub-pp033_task-walkSlow_left
# 309: sub-pp033_task-walkSlow_right

# %%
df_out = pd.DataFrame({
    "sub": sub_ids,
    "filename": filenames,
    "side": sides,
    "event_type": event_types,
    "ix_ref": ix_refs,
    "ix_pred": ix_preds
})
df_out.head()
# Out:
#      sub                 filename  side event_type ix_ref ix_pred
# 0  pp156  sub-pp156_task-walkFast  left         IC    139     n/a
# 1  pp156  sub-pp156_task-walkFast  left         IC    329     n/a
# 2  pp156  sub-pp156_task-walkFast  left         IC    514     n/a
# 3  pp156  sub-pp156_task-walkFast  left         IC    700     n/a
# 4  pp156  sub-pp156_task-walkFast  left         IC    882     881

# %%
df_out.to_csv("gait_event_detection.tsv", sep="\t")

# %%
len(df_out)
# Out:
# 2983
